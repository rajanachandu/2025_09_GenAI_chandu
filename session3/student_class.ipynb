# %%
#Create a class called student. Takes two input name and grade
#display name and grade of the student

class Student:
   def __init__(self, name, grade):
       self.name = name
       self.grade = grade

   def print(self):
        print (f"name {self.name} grade {self.grade}")


Ana = Student("Ana", 9)
Ana.print()
# Out:
# name Ana grade 9
